# %% [markdown]
# ### ¿Cual es la categoria del nivel de poblacion de una entidad en 2010 observada por primera vez?
# (Bajo, Medio, Alto)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('indicadores.csv', sep=',', encoding='latin-1')
df
# Out:
#       ent         nom_ent  mun  clave_mun                nom_mun  \
# 0       1  Aguascalientes    1       1001         Aguascalientes
# 1       1  Aguascalientes    2       1002               Asientos
# 2       1  Aguascalientes    3       1003               Calvillo
# 3       1  Aguascalientes    4       1004                  Cosío
# 4       1  Aguascalientes    5       1005            Jesús María
# ...   ...             ...  ...        ...                    ...
# 2451   32       Zacatecas   54      32054          Villa Hidalgo
# 2452   32       Zacatecas   55      32055             Villanueva
# 2453   32       Zacatecas   56      32056              Zacatecas
# 2454   32       Zacatecas   57      32057               Trancoso
# 2455   32       Zacatecas   58      32058  Santa María de la Paz
#
#       pobtot_ajustada    pobreza  pobreza_e  pobreza_m    vul_car  ...  \
# 0              794304  30.531104   2.264478  28.266627  27.983320  ...
# 1               48592  67.111172   8.040704  59.070468  22.439389  ...
# 2               53104  61.360527   7.241238  54.119289  29.428583  ...
# 3               14101  52.800458   4.769001  48.031458  27.128568  ...
# 4              101379  45.338512   6.084037  39.254475  26.262912  ...
# ...               ...        ...        ...        ...        ...  ...
# 2451            21016  74.848837  12.301183  62.547654  19.229856  ...
# 2452            27385  65.450191  10.203506  55.246687  23.623556  ...
# 2453           117528  29.541959   3.535624  26.006335  16.644262  ...
# 2454            20456  78.374962  14.607016  63.767946  13.750759  ...
# 2455             2772  62.204207  10.102023  52.102184  27.489635  ...
#
#       pobreza_alim_10  pobreza_cap_90  pobreza_cap_00  pobreza_cap_10  \
# 0           11.805700            20.4            12.7       18.474600
# 1           21.993299            39.9            29.0       30.980801
# 2           19.266800            39.5            33.1       28.259199
# 3           14.303200            35.2            21.0       22.386101
# 4           15.085100            36.6            22.6       22.139999
# ...               ...             ...             ...             ...
# 2451        30.055300            51.8            54.8       41.368999
# 2452        13.138800            34.2            25.9       20.563601
# 2453         7.164800            15.7            20.7       12.115300
# 2454        21.285900            36.2            36.4       30.037100
# 2455        18.688299            37.6            44.8       26.998899
#
#       pobreza_patrim_90  pobreza_patrim_00  pobreza_patrim_10  gini_90  \
# 0                  43.4               33.7          41.900398    0.473
# 1                  64.2               48.9          59.175800    0.379
# 2                  63.9               57.9          56.504902    0.414
# 3                  59.7               40.1          51.164501    0.392
# 4                  60.6               42.2          45.703899    0.391
# ...                 ...                ...                ...      ...
# 2451               73.5               70.9          70.859596    0.403
# 2452               57.8               44.1          46.659199    0.422
# 2453               36.6               41.8          32.302700    0.528
# 2454               60.5               54.7          57.394501    0.380
# 2455               61.2               63.9          54.116299    0.431
#
#       gini_00   gini_10
# 0       0.425  0.422628
# 1       0.533  0.343879
# 2       0.465  0.386781
# 3       0.541  0.344984
# 4       0.469  0.458083
# ...       ...       ...
# 2451    0.589  0.342037
# 2452    0.463  0.362527
# 2453    0.498  0.436339
# 2454    0.483  0.365307
# 2455    0.500  0.385067
#
# [2456 rows x 139 columns]

# %%
columna_58 = df.iloc[:, 58]
df_y = pd.DataFrame(columna_58, columns=['pobtot_10'])
df_y.index = range(len(df_y))  
display(df_y)
# Out:
#       pobtot_10
# 0        797010
# 1         45492
# 2         54136
# 3         15042
# 4         99590
# ...         ...
# 2451      18490
# 2452      29395
# 2453     138176
# 2454      16934
# 2455       2821
#
# [2456 rows x 1 columns]

# %%
# spaces in the dataset
datos_nulos = df.isna().sum().sum()
print("Total of null values:", datos_nulos)
# Out:
# Total of null values: 305

# %%
matriz_correlacion = df.cor
columnas_rel = matriz_correlacion['pobtot_10']
correlaciones_ordenadas = columnas_rel.abs().sort_values(ascending=False)
print(correlaciones_ordenadas)
# Out:
# pobtot_10              1.000000
# pobtot_05              0.996988
# pobtot_ajustada        0.996085
# pobtot_00              0.988611
# N_carencias            0.986714
#                          ...
# porc_vivsnenergia05    0.063340
# ic_asalud              0.056544
# p_viv_techos_00        0.055109
# gini_00                0.043514
# p_viv_techos_10        0.040210
# Name: pobtot_10, Length: 134, dtype: float64

# %%
# Definimos un umbral de 0.7 ya que esto nos indica una correlacion significativa.
umbral_correlacion = 0.7
columnas_interes = correlaciones_ordenadas[correlaciones_ordenadas > umbral_correlacion].index.tolist()

# New dataframe
new_df = df[columnas_interes]
new_df
# Out:
#       pobtot_10  pobtot_05  pobtot_ajustada  pobtot_00  N_carencias  \
# 0        797010   723043.0           794304   643419.0       464782
# 1         45492    40547.0            48592    37763.0        43514
# 2         54136    50183.0            53104    51291.0        48213
# 3         15042    13687.0            14101    12619.0        11271
# 4         99590    82623.0           101379    64097.0        72589
# ...         ...        ...              ...        ...          ...
# 2451      18490    17195.0            21016    15746.0        19772
# 2452      29395    28760.0            27385    32140.0        24393
# 2453     138176   132035.0           117528   123899.0        54282
# 2454      16934    15362.0            20456    13080.0        18845
# 2455       2821     2601.0             2772        NaN         2486
#
#       N_vul_car  N_ic_segsoc  N_pobreza_m   N_plb  N_ic_asalud  N_npnv  \
# 0        222273       332018       224523  309383       190907  262648
# 1         10904        37903        28704   35311         7539    2377
# 2         15628        42511        28740   34136        11052    3340
# 3          3825         9283         6773    8532         1984    1743
# 4         26625        53343        39796   54358        16796   20396
# ...         ...          ...          ...     ...          ...     ...
# 2451       4041        16088        13145   16398         7578     577
# 2452       6469        20414        15129   19295        14600    1621
# 2453      19562        38392        30565   45095        21527   52871
# 2454       2813        17027        13044   16941         2408     702
# 2455        762         2113         1444    1788         1242     222
#
#       N_ic_rezedu  N_pobreza  N_ic_ali  N_vul_ing  N_carencias3  N_plb_m  \
# 0          118912     242510    140318      66873         79897    81924
# 1           10313      32611     15380       2701          9222    15648
# 2           14530      32585     10831       1551         10090    14074
# 3            2946       7445      2681       1087          1983     2941
# 4           20862      45964     25744       8394         15995    19738
# ...           ...        ...       ...        ...           ...      ...
# 2451         5748      15730      8004        668          5761     8063
# 2452         8192      17924      5179       1371          7442     8052
# 2453        14028      34720     21596      10375         11498    12534
# 2454         5452      16032      6144        908          5018     9319
# 2455          788       1724       443         64           708      742
#
#       N_ic_cv
# 0       37501
# 1        5375
# 2        5247
# 3        1614
# 4       13115
# ...       ...
# 2451     1194
# 2452      782
# 2453     2841
# 2454     2190
# 2455      247
#
# [2456 rows x 18 columns]

# %%
null_values = new_df.isnull().sum()
print(null_values)
# Out:
# pobtot_10           0
# pobtot_05           2
# pobtot_ajustada     0
# pobtot_00          14
# N_carencias         0
# N_vul_car           0
# N_ic_segsoc         0
# N_pobreza_m         0
# N_plb               0
# N_ic_asalud         0
# N_npnv              0
# N_ic_rezedu         0
# N_pobreza           0
# N_ic_ali            0
# N_vul_ing           0
# N_carencias3        0
# N_plb_m             0
# N_ic_cv             0
# dtype: int64

# %%
#Calculate the mean of the numeric columns
columnas_numericas = new_df.select_dtypes(include=[np.number])
promedios = columnas_numericas.mean()

#Fill the null vallues in the dataset
new_df.loc[:, columnas_numericas.columns] = 
new_df.loc[:, columnas_numericas.columns].fillna(promedios)
# Out:
# C:\RoboDK\Python37\lib\site-packages\pandas\core\indexing.py:1884: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %%
#Comprueba si hay espacios en blanco
null_values = new_df.isnull().sum()
print(null_values)
# Out:
# pobtot_10          0
# pobtot_05          0
# pobtot_ajustada    0
# pobtot_00          0
# N_carencias        0
# N_vul_car          0
# N_ic_segsoc        0
# N_pobreza_m        0
# N_plb              0
# N_ic_asalud        0
# N_npnv             0
# N_ic_rezedu        0
# N_pobreza          0
# N_ic_ali           0
# N_vul_ing          0
# N_carencias3       0
# N_plb_m            0
# N_ic_cv            0
# dtype: int64

# %%
new_df
# Out:
#       pobtot_10  pobtot_05  pobtot_ajustada     pobtot_00  N_carencias  \
# 0        797010   723043.0           794304  643419.00000       464782
# 1         45492    40547.0            48592   37763.00000        43514
# 2         54136    50183.0            53104   51291.00000        48213
# 3         15042    13687.0            14101   12619.00000        11271
# 4         99590    82623.0           101379   64097.00000        72589
# ...         ...        ...              ...           ...          ...
# 2451      18490    17195.0            21016   15746.00000        19772
# 2452      29395    28760.0            27385   32140.00000        24393
# 2453     138176   132035.0           117528  123899.00000        54282
# 2454      16934    15362.0            20456   13080.00000        18845
# 2455       2821     2601.0             2772   39918.21335         2486
#
#       N_vul_car  N_ic_segsoc  N_pobreza_m   N_plb  N_ic_asalud  N_npnv  \
# 0        222273       332018       224523  309383       190907  262648
# 1         10904        37903        28704   35311         7539    2377
# 2         15628        42511        28740   34136        11052    3340
# 3          3825         9283         6773    8532         1984    1743
# 4         26625        53343        39796   54358        16796   20396
# ...         ...          ...          ...     ...          ...     ...
# 2451       4041        16088        13145   16398         7578     577
# 2452       6469        20414        15129   19295        14600    1621
# 2453      19562        38392        30565   45095        21527   52871
# 2454       2813        17027        13044   16941         2408     702
# 2455        762         2113         1444    1788         1242     222
#
#       N_ic_rezedu  N_pobreza  N_ic_ali  N_vul_ing  N_carencias3  N_plb_m  \
# 0          118912     242510    140318      66873         79897    81924
# 1           10313      32611     15380       2701          9222    15648
# 2           14530      32585     10831       1551         10090    14074
# 3            2946       7445      2681       1087          1983     2941
# 4           20862      45964     25744       8394         15995    19738
# ...           ...        ...       ...        ...           ...      ...
# 2451         5748      15730      8004        668          5761     8063
# 2452         8192      17924      5179       1371          7442     8052
# 2453        14028      34720     21596      10375         11498    12534
# 2454         5452      16032      6144        908          5018     9319
# 2455          788       1724       443         64           708      742
#
#       N_ic_cv
# 0       37501
# 1        5375
# 2        5247
# 3        1614
# 4       13115
# ...       ...
# 2451     1194
# 2452      782
# 2453     2841
# 2454     2190
# 2455      247
#
# [2456 rows x 18 columns]

# %%
def categorizar_valor(valor):
    if valor < 10000:
        return "baja"
    elif valor < 100000:
        return "media"
    else:
        return "alta"

new_df['pobtot_10'] = new_df['pobtot_10'].apply(categorizar_valor)
# Definir las variables x e y
y = new_df["pobtot_10"]
x = new_df.drop("pobtot_10", axis=1)
new_df = pd.concat([x, y], axis=1)
# Out:
# C:\Users\Erubiel Tun\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":

# %%
new_df
# Out:
#       pobtot_05  pobtot_ajustada     pobtot_00  N_carencias  N_vul_car  \
# 0      723043.0           794304  643419.00000       464782     222273
# 1       40547.0            48592   37763.00000        43514      10904
# 2       50183.0            53104   51291.00000        48213      15628
# 3       13687.0            14101   12619.00000        11271       3825
# 4       82623.0           101379   64097.00000        72589      26625
# ...         ...              ...           ...          ...        ...
# 2451    17195.0            21016   15746.00000        19772       4041
# 2452    28760.0            27385   32140.00000        24393       6469
# 2453   132035.0           117528  123899.00000        54282      19562
# 2454    15362.0            20456   13080.00000        18845       2813
# 2455     2601.0             2772   39918.21335         2486        762
#
#       N_ic_segsoc  N_pobreza_m   N_plb  N_ic_asalud  N_npnv  N_ic_rezedu  \
# 0          332018       224523  309383       190907  262648       118912
# 1           37903        28704   35311         7539    2377        10313
# 2           42511        28740   34136        11052    3340        14530
# 3            9283         6773    8532         1984    1743         2946
# 4           53343        39796   54358        16796   20396        20862
# ...           ...          ...     ...          ...     ...          ...
# 2451        16088        13145   16398         7578     577         5748
# 2452        20414        15129   19295        14600    1621         8192
# 2453        38392        30565   45095        21527   52871        14028
# 2454        17027        13044   16941         2408     702         5452
# 2455         2113         1444    1788         1242     222          788
#
#       N_pobreza  N_ic_ali  N_vul_ing  N_carencias3  N_plb_m  N_ic_cv pobtot_10
# 0        242510    140318      66873         79897    81924    37501      alta
# 1         32611     15380       2701          9222    15648     5375     media
# 2         32585     10831       1551         10090    14074     5247     media
# 3          7445      2681       1087          1983     2941     1614     media
# 4         45964     25744       8394         15995    19738    13115     media
# ...         ...       ...        ...           ...      ...      ...       ...
# 2451      15730      8004        668          5761     8063     1194     media
# 2452      17924      5179       1371          7442     8052      782     media
# 2453      34720     21596      10375         11498    12534     2841      alta
# 2454      16032      6144        908          5018     9319     2190     media
# 2455       1724       443         64           708      742      247      baja
#
# [2456 rows x 18 columns]

# %%
y = new_df["pobtot_10"]
x = new_df.drop("pobtot_10", axis=1)

# %%
new_df.columns[0:17]
# Out:
# Index(['pobtot_05', 'pobtot_ajustada', 'pobtot_00', 'N_carencias', 'N_vul_car',
#        'N_ic_segsoc', 'N_pobreza_m', 'N_plb', 'N_ic_asalud', 'N_npnv',
#        'N_ic_rezedu', 'N_pobreza', 'N_ic_ali', 'N_vul_ing', 'N_carencias3',
#        'N_plb_m', 'N_ic_cv'],
#       dtype='object')

# %%
X_train = new_df.iloc[:1964, 0:17].values
X_test = new_df.iloc[1964:, 0:17].values

y_train = new_df.iloc[:1964, 17].values
y_test = new_df.iloc[1964:, 17].values

# %%
def eucledian(p1,p2):
    dist = np.sqrt(np.sum((p1-p2)**2))
    return dist
 
def predict(x_train, y , x_input, k):
    op_labels = []
     
    for item in x_input: 
         
        #distances storage
        point_dist = []
         
        #data to be processed
        for j in range(len(x_train)): 
            distances = eucledian(np.array(x_train[j,:]) , item) 
            #Calculating the distance
            point_dist.append(distances) 
        point_dist = np.array(point_dist) 
         
        #preserve the index
        dist = np.argsort(point_dist)[:k] 
         
        labels = y[dist]
         
        #voting
        unique_labels, label_counts = np.unique(labels, return_counts=True)
        most_common_label = unique_labels[np.argmax(label_counts)]
        
        op_labels.append(most_common_label)
 
    return op_labels

# %%
predictions = predict(X_train, y_train, X_test, k=5)
predictions
# Out:
# ['alta',
#  'alta',
#  'media',
#  'alta',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'alta',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'alta',
#  'baja',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'alta',
#  'alta',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'alta',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'alta',
#  'alta',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'alta',
#  'media',
#  'media',
#  'alta',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'alta',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'alta',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'alta',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'alta',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'alta',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'alta',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'alta',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'alta',
#  'baja',
#  'media',
#  'media',
#  'alta',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'alta',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'alta',
#  'baja',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'media',
#  'baja',
#  'baja',
#  'baja',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'media',
#  'alta',
#  'media',
#  'media']

# %%
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 97.56%

# %% [markdown]
# #### -Implementation of the model with librarie.

# %%
from sklearn.neighbors import KNeighborsClassifier

# Training and test data
X_train = new_df.iloc[:1964, 0:17].values
y_train = new_df.iloc[:1964, 17].values
X_test = new_df.iloc[1964:, 0:17].values
y_test = new_df.iloc[1964:, 17].values

# k=5
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
predictions = knn.predict(X_test)

print(predictions)
predictions = knn.predict(X_test)

#Accuracy
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# ['alta' 'alta' 'media' 'alta' 'media' 'media' 'media' 'alta' 'alta'
#  'media' 'media' 'media' 'media' 'media' 'media' 'alta' 'baja' 'baja'
#  'baja' 'media' 'baja' 'alta' 'baja' 'baja' 'media' 'media' 'baja' 'media'
#  'media' 'media' 'baja' 'media' 'baja' 'alta' 'alta' 'baja' 'baja' 'media'
#  'baja' 'alta' 'baja' 'media' 'media' 'baja' 'alta' 'alta' 'media' 'media'
#  'baja' 'media' 'alta' 'media' 'media' 'alta' 'baja' 'media' 'baja'
#  'media' 'baja' 'media' 'media' 'media' 'media' 'media' 'baja' 'media'
#  'baja' 'baja' 'media' 'media' 'media' 'baja' 'media' 'media' 'media'
#  'baja' 'media' 'baja' 'media' 'media' 'media' 'media' 'media' 'media'
#  'media' 'media' 'media' 'media' 'media' 'media' 'baja' 'media' 'baja'
#  'media' 'media' 'baja' 'media' 'media' 'media' 'media' 'baja' 'baja'
#  'baja' 'media' 'baja' 'media' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja'
#  'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'media' 'media' 'baja' 'media'
#  'baja' 'baja' 'media' 'media' 'media' 'baja' 'media' 'media' 'media'
#  'media' 'baja' 'baja' 'baja' 'baja' 'media' 'media' 'media' 'media'
#  'media' 'media' 'media' 'alta' 'media' 'media' 'media' 'media' 'media'
#  'media' 'media' 'baja' 'baja' 'media' 'alta' 'media' 'baja' 'baja'
#  'media' 'alta' 'media' 'media' 'media' 'alta' 'media' 'media' 'media'
#  'media' 'media' 'media' 'media' 'baja' 'media' 'media' 'media' 'media'
#  'media' 'media' 'media' 'baja' 'media' 'media' 'media' 'media' 'media'
#  'media' 'media' 'media' 'media' 'baja' 'media' 'media' 'media' 'media'
#  'baja' 'media' 'media' 'media' 'media' 'baja' 'media' 'media' 'alta'
#  'baja' 'media' 'media' 'media' 'media' 'media' 'media' 'media' 'baja'
#  'media' 'baja' 'media' 'media' 'media' 'alta' 'media' 'media' 'media'
#  'baja' 'baja' 'alta' 'media' 'baja' 'media' 'media' 'baja' 'media'
#  'media' 'media' 'media' 'alta' 'baja' 'media' 'media' 'media' 'alta'
#  'alta' 'media' 'media' 'media' 'media' 'media' 'media' 'alta' 'media'
#  'media' 'media' 'media' 'baja' 'baja' 'media' 'baja' 'baja' 'alta'
#  'media' 'media' 'media' 'media' 'baja' 'media' 'media' 'media' 'media'
#  'media' 'media' 'baja' 'media' 'alta' 'baja' 'media' 'media' 'media'
#  'alta' 'media' 'baja' 'baja' 'media' 'baja' 'baja' 'media' 'media'
#  'media' 'media' 'baja' 'media' 'media' 'media' 'media' 'baja' 'media'
#  'media' 'baja' 'media' 'media' 'media' 'media' 'baja' 'baja' 'baja'
#  'baja' 'media' 'alta' 'baja' 'media' 'media' 'alta' 'media' 'baja'
#  'media' 'media' 'baja' 'media' 'media' 'media' 'media' 'media' 'media'
#  'media' 'media' 'media' 'media' 'media' 'media' 'media' 'media' 'baja'
#  'media' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja'
#  'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'media' 'baja' 'baja'
#  'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja'
#  'media' 'media' 'baja' 'baja' 'baja' 'baja' 'media' 'baja' 'media'
#  'media' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'media' 'baja' 'alta'
#  'baja' 'media' 'media' 'baja' 'baja' 'media' 'baja' 'media' 'media'
#  'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'baja'
#  'baja' 'baja' 'baja' 'baja' 'baja' 'baja' 'media' 'baja' 'baja' 'media'
#  'baja' 'baja' 'baja' 'baja' 'baja' 'media' 'baja' 'baja' 'baja' 'media'
#  'baja' 'baja' 'baja' 'media' 'baja' 'baja' 'media' 'baja' 'media' 'baja'
#  'baja' 'media' 'media' 'baja' 'media' 'baja' 'baja' 'baja' 'baja' 'baja'
#  'baja' 'media' 'baja' 'media' 'media' 'media' 'alta' 'baja' 'baja' 'baja'
#  'media' 'baja' 'media' 'alta' 'baja' 'media' 'media' 'baja' 'media'
#  'baja' 'media' 'media' 'media' 'baja' 'baja' 'media' 'baja' 'baja'
#  'media' 'baja' 'media' 'media' 'media' 'media' 'media' 'media' 'media'
#  'baja' 'media' 'baja' 'media' 'baja' 'baja' 'baja' 'media' 'media'
#  'media' 'media' 'media' 'media' 'media' 'media' 'alta' 'media' 'media']
# Accuracy: 97.56%

# %% [markdown]
# #### -The same model with Hamming metric

# %%
X_train = new_df.iloc[:1964, 0:17].values
X_test = new_df.iloc[1964:, 0:17].values

y_train = new_df.iloc[:1964, 17].values
y_test = new_df.iloc[1964:, 17].values

def hamming_distance(p1, p2):
    return np.sum(p1 != p2)

# Función para predecir utilizando KNN con distancia de Hamming
def predict(x_train, y, x_input, k):
    op_labels = []

    for item in x_input:
        point_dist = []
        for j in range(len(x_train)):
            distance = hamming_distance(np.array(x_train[j, :]), item)
            # Calcula la distancia de Hamming
            point_dist.append(distance)
        point_dist = np.array(point_dist)

        dist = np.argsort(point_dist)[:k]
        labels = y[dist]
        # Votación
        unique_labels, label_counts = np.unique(labels, return_counts=True)
        most_common_label = unique_labels[np.argmax(label_counts)]
        op_labels.append(most_common_label)

    return op_labels

# test and trainig data
X_train = X_train.astype(str) 
X_test = X_test.astype(str)
k = 3  
y_pred = predict(X_train, y_train, X_test, k)
#acuracy
accuracy = np.mean(y_pred == y_test)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.5426829268292683
